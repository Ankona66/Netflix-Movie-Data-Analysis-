# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
#Dataframe
df = pd.read_csv('mymoviedb.csv', lineterminator= '\n')
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9827 entries, 0 to 9826
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   object
#  1   Title              9827 non-null   object
#  2   Overview           9827 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   int64
#  5   Vote_Average       9827 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9827 non-null   object
#  8   Poster_Url         9827 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 691.1+ KB

# %%
# To check duplicates
df.duplicated().sum
#Shows statistical data
df.describe(include='all')
# Out:
#        Release_Date                Title  \
# count          9827                 9827
# unique         5893                 9513
# top      2022-03-10  Alice in Wonderland
# freq             16                    4
# mean            NaN                  NaN
# std             NaN                  NaN
# min             NaN                  NaN
# 25%             NaN                  NaN
# 50%             NaN                  NaN
# 75%             NaN                  NaN
# max             NaN                  NaN
#
#                                                  Overview   Popularity  \
# count                                                9827  9827.000000
# unique                                               9822          NaN
# top     Alien pods come to Earth and, naturally, start...          NaN
# freq                                                    2          NaN
# mean                                                  NaN    40.326088
# ...

# %%
#Summary of work TBD
# Release date to be casted in Date and time format
# overview, Original Language, Poster Url can be removed
# Genre column has a white space and that needs to be removed if required

#Changing the format of Release date to Date Time
df['Release_Date'] = pd.to_datetime(df['Release_Date'])
print(df['Release_Date'] )

#Just extracting the year
df['Release_Date'] = df['Release_Date'].dt.year
# Out:
# 0      2021-12-15
# 1      2022-03-01
# 2      2022-02-25
# 3      2021-11-24
# 4      2021-12-22
#           ...
# 9822   1973-10-15
# 9823   2020-10-01
# 9824   2016-05-06
# 9825   2021-03-31
# 9826   1984-09-23
# Name: Release_Date, Length: 9827, dtype: datetime64[ns]

# %%
df.head()
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2022               The Batman
# 2          2022                  No Exit
# 3          2021                  Encanto
# 4          2021           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
#Removing the columns
cols = ['Overview', 'Original_Language', 'Poster_Url']
df.drop(cols, axis=1, inplace = True)
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2022               The Batman    3827.658        1151
# 2          2022                  No Exit    2618.087         122
# 3          2021                  Encanto    2402.201        5076
# 4          2021           The King's Man    1895.511        1793
#
#    Vote_Average                               Genre
# 0           8.3  Action, Adventure, Science Fiction
# 1           8.1            Crime, Mystery, Thriller
# 2           6.3                            Thriller
# 3           7.7  Animation, Comedy, Family, Fantasy
# 4           7.0    Action, Adventure, Thriller, War

# %% [markdown]
# Categorizing the Vote_Average Column in 4 categories

# %%
def categorize_col(df, col, labels):
    edges = [df[col].describe()['25%']]
    # df[col].describe()['50%'],
    # df[col].describe()['75%'],
    # df[col].describe()['max']]
    # df[col] = pd.cut(df[col], edges, labels = labels, duplicates = 'drop')
    return edges

# %%
labels = ['not_popular', 'below_avg', 'average', 'popular']
x = categorize_col(df, 'Vote_Average',labels)
print(x[1])
# df['Vote_Average'].unique
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'min'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.describe()
# Out:
#        Release_Date   Popularity    Vote_Count
# count   9827.000000  9827.000000   9827.000000
# mean    2006.203623    40.326088   1392.805536
# std       15.685554   108.873998   2611.206907
# min     1902.000000    13.354000      0.000000
# 25%     2000.000000    16.128500    146.000000
# 50%     2011.000000    21.199000    444.000000
# 75%     2017.000000    35.191500   1376.000000
# max     2024.000000  5083.954000  31077.000000
